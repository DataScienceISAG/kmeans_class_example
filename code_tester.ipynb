# %%
import numpy as np

# %%
from isag_kmeans import IsagKmeans

# %%
model = IsagKmeans(2)

# %%
model.max_iterations
# Out:
# 1000

# %%
data_1 = np.random.rand(1000,2) * 8
data_2 = np.random.rand(1000,2) * 10
data = np.append(data_1,data_2,axis = 0)

# %%
model.fit(data)

# %%
labels = model.predict(data, True)

# %%
sum(labels)
# Out:
# 975.0
